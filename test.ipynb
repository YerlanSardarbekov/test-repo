# %%
#Will try to work with API

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import json
from IPython.display import display, HTML

# %% [markdown]
# Working with API??

# %%
url = 'https://api.opendota.com/api/matches/6617734026'

match_response = requests.get(url)
print(match_response.status_code)
# Out:
# 200

# %%
match_data = match_response.json()

print(type(match_data))
print(len(match_data))
print(match_data.keys())
# Out:
# <class 'dict'>
# 57
# dict_keys(['match_id', 'barracks_status_dire', 'barracks_status_radiant', 'chat', 'cluster', 'cosmetics', 'dire_score', 'dire_team_id', 'draft_timings', 'duration', 'engine', 'first_blood_time', 'game_mode', 'human_players', 'leagueid', 'lobby_type', 'match_seq_num', 'negative_votes', 'objectives', 'picks_bans', 'positive_votes', 'radiant_gold_adv', 'radiant_score', 'radiant_team_id', 'radiant_win', 'radiant_xp_adv', 'skill', 'start_time', 'teamfights', 'tower_status_dire', 'tower_status_radiant', 'version', 'players', 'pre_game_duration', 'flags', 'radiant_name', 'radiant_logo', 'radiant_team_complete', 'dire_name', 'dire_logo', 'dire_team_complete', 'radiant_captain', 'dire_captain', 'od_data', 'league', 'radiant_team', 'dire_team', 'series_id', 'series_type', 'replay_salt', 'metadata', 'patch', 'region', 'all_word_counts', 'my_word_counts', 'comeback', 'stomp'])

# %%
print(match_data)
# Out:
# {'match_id': 6617734026, 'barracks_status_dire': 63, 'barracks_status_radiant': 15, 'chat': [{'time': -581, 'type': 'chat', 'unit': 'nEwWOfficial', 'key': 'Misha please restart your cam, as it seems not to work. Your face has to be centered in the camera shot', 'slot': 10}, {'time': -540, 'type': 'chat', 'key': 'done', 'slot': 1, 'player_slot': 1}, {'time': -249, 'type': 'chat', 'unit': 'nEwWOfficial', 'key': 'Misha, your cam seems to not work again. It´s only a greenscreen. Please have a look at it', 'slot': 10}, {'time': -231, 'type': 'chat', 'key': 'it laggs, trying to restart it ', 'slot': 1, 'player_slot': 1}, {'time': -170, 'type': 'chatwheel', 'key': '414', 'slot': 3, 'player_slot': 3}, {'time': -74, 'type': 'chat', 'key': 'GL', 'slot': 2, 'player_slot': 2}, {'time': -68, 'type': 'chatwheel', 'key': '71', 'slot': 4, 'player_slot': 4}, {'time': -67, 'type': 'chatwheel', 'key': '71', 'slot': 4, 'player_slot': 4}, {'time': 11, 'type': 'chatwheel', 'key': '71', 'slot': 0, 'player_
# ...

# %%
url = 'https://api.opendota.com/api/live'

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
live_matches = response.json()

# %%
print([item["average_mmr"] for item in live_matches])
# Out:
# [6640, 7057, 7907, 7892, 7732, 7311, 7762, 8177, 7976, 7258, 7783, 7641, 8035, 7999, 7687, 7837, 7243, 8109, 7758, 7496, 8262, 7114, 6894, 6971, 7594, 8041, 7981, 6877, 7922, 8107, 7060, 6963, 7355, 7778, 7803, 6970, 7860, 8039, 7941, 7179, 7625, 6783, 8084, 6823, 7940, 7388, 7673, 7583, 8135, 7888, 7913, 7436, 8328, 7924, 7439, 7366, 8056, 7685, 8137, 7665, 8003, 7556, 7018, 7417, 7375, 7425, 7697, 7904, 7638, 7961, 7265, 8028, 7916, 7152, 8108, 8002, 0, 7974, 7760, 8113, 7620, 7628, 8216, 7370, 7868, 7981, 7168, 7846, 7953, 6938, 7639, 7720, 7864, 7670, 7002, 8034, 7008, 7710, 8008, 7200]

# %%
url = 'https://api.opendota.com/api/heroes'
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
hero_data = response.json()

print([item['localized_name'] for item in hero_data])
# Out:
# ['Anti-Mage', 'Axe', 'Bane', 'Bloodseeker', 'Crystal Maiden', 'Drow Ranger', 'Earthshaker', 'Juggernaut', 'Mirana', 'Morphling', 'Shadow Fiend', 'Phantom Lancer', 'Puck', 'Pudge', 'Razor', 'Sand King', 'Storm Spirit', 'Sven', 'Tiny', 'Vengeful Spirit', 'Windranger', 'Zeus', 'Kunkka', 'Lina', 'Lion', 'Shadow Shaman', 'Slardar', 'Tidehunter', 'Witch Doctor', 'Lich', 'Riki', 'Enigma', 'Tinker', 'Sniper', 'Necrophos', 'Warlock', 'Beastmaster', 'Queen of Pain', 'Venomancer', 'Faceless Void', 'Wraith King', 'Death Prophet', 'Phantom Assassin', 'Pugna', 'Templar Assassin', 'Viper', 'Luna', 'Dragon Knight', 'Dazzle', 'Clockwerk', 'Leshrac', "Nature's Prophet", 'Lifestealer', 'Dark Seer', 'Clinkz', 'Omniknight', 'Enchantress', 'Huskar', 'Night Stalker', 'Broodmother', 'Bounty Hunter', 'Weaver', 'Jakiro', 'Batrider', 'Chen', 'Spectre', 'Ancient Apparition', 'Doom', 'Ursa', 'Spirit Breaker', 'Gyrocopter', 'Alchemist', 'Invoker', 'Silencer', 'Outworld Destroyer', 'Lycan', 'Brewmaster', 'Shadow D
# ...

# %%
print(len(hero_data))
# Out:
# 126
